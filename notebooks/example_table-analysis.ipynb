# %%
# %matplotlib inline

import zipfile
import numpy as np
import pylab as plt
import pandas as pd

from glob import glob

# %%
zip_ref = zipfile.ZipFile('./datasets/UN.zip', 'r')
zip_ref.extractall('./datasets/')

# %%
glob('./datasets/*')
# Out:
# ['./datasets/monthly-milk-production-pounds.csv',
#  './datasets/significant-earthquakes.csv',
#  './datasets/2014_world_gdp_with_codes.csv',
#  './datasets/tesla-stock-price.csv',
#  './datasets/maternal_health.csv',
#  './datasets/earthquake.csv',
#  './datasets/migrants.csv',
#  './datasets/UN.zip',
#  './datasets/disease.csv',
#  './datasets/gapminderDataFiveYear.csv',
#  './datasets/diabetes.csv',
#  './datasets/su5m.csv',
#  './datasets/UN']

# %%
countries = ['Afghanistan', 'Albania',
       'Algeria', 'Andorra', 'Angola', 'Anguilla', 'Antigua and Barbuda',
       'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria',
       'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
       'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
       'Bolivia (Plurin. State of)', 'Bosnia and Herzegovina', 'Botswana',
       'Brazil', 'British Virgin Islands', 'Brunei Darussalam',
       'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia',
       'Cameroon', 'Canada', 'Cayman Islands', 'Central African Republic',
       'Chad', 'Chile', 'China', 'China, Hong Kong SAR',
       'China, Macao SAR', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
       'Costa Rica', 'Croatia', 'Cuba',
       'Cyprus', 'Czechia', "Dem. People's Rep. Korea",
       'Dem. Rep. of the Congo', 'Denmark', 'Djibouti', 'Dominica',
       'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador',
       'Equatorial Guinea', 'Eritrea', 'Estonia', 'Ethiopia',
       'Falkland Islands (Malvinas)', 'Faroe Islands', 'Fiji', 'Finland',
       'France', 'French Polynesia', 'Gabon', 'Gambia', 'Georgia',
       'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
       'Guam', 'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau',
       'Guyana', 'Haiti', 'Honduras', 'Hungary', 'Iceland', 'India',
       'Indonesia', 'Iran (Islamic Republic of)', 'Iraq', 'Ireland',
       'Israel', 'Italy', 'Jamaica', 'Japan', 'Jersey', 'Jordan',
       'Kazakhstan', 'Kenya', 'Kiribati', 'Kuwait', 'Kyrgyzstan',
       "Lao People's Dem. Rep.", 'Latvia', 'Lebanon', 'Lesotho',
       'Liberia', 'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg',
       'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
       'Marshall Islands', 'Mauritania', 'Mauritius', 'Mayotte', 'Mexico',
       'Micronesia (Fed. States of)', 'Monaco', 'Mongolia', 'Montenegro',
       'Montserrat', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia',
       'Nauru', 'Nepal', 'Netherlands', 'Netherlands Antilles [former]',
       'New Caledonia', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria',
       'Niue', 'North Macedonia', 'Norway', 'Oman',
       'Other non-specified areas', 'Pakistan', 'Palau', 'Panama',
       'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland',
       'Portugal', 'Puerto Rico', 'Qatar', 'Republic of Korea',
       'Republic of Moldova', 'Réunion', 'Romania', 'Russian Federation',
       'Rwanda', 'Saint Helena', 'Ascension', 'Saint Kitts and Nevis',
       'Saint Lucia', 'Saint Vincent & Grenadines', 'Samoa', 'San Marino',
       'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
       'Seychelles', 'Sierra Leone', 'Singapore', 'Slovakia', 'Slovenia',
       'Solomon Islands', 'Somalia', 'South Africa', 'South Sudan',
       'Spain', 'Sri Lanka', 'State of Palestine', 'Sudan', 'Suriname',
       'Eswatini', 'Sweden', 'Switzerland', 'Syrian Arab Republic',
       'Tajikistan', 'Thailand', 'Timor-Leste', 'Togo', 'Tokelau',
       'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey',
       'Turkmenistan', 'Tuvalu', 'Uganda', 'Ukraine',
       'United Arab Emirates', 'United Kingdom',
       'United Rep. of Tanzania', 'United States of America',
       'United States Virgin Islands', 'Uruguay', 'Uzbekistan', 'Vanuatu',
       'Venezuela (Boliv. Rep. of)', 'Viet Nam',
       'Wallis and Futuna Islands', 'Yemen', 'Zambia', 'Zimbabwe']

# %% [markdown]
# ### Internet

# %%
filename = './datasets/UN/SYB62_T29_201904_Internet Usage.csv'
df = pd.read_csv(filename,encoding='latin1',header=[1])
df = df.rename(columns={'Unnamed: 1':'country','Value':'internetusage'})
df = df[df['country'].isin(countries)]
df.columns
# Out:
# Index(['Region/Country/Area', 'country', 'Year', 'Series', 'internetusage',
#        'Footnotes', 'Source'],
#       dtype='object')

# %%
df_internet = df[['country', 'Year', 'internetusage']]
del df

# %% [markdown]
# ### CPI

# %%
filename = './datasets/UN/SYB61_T19_Consumer Price Index.csv'
df = pd.read_csv(filename,encoding='latin1',header=[1])
df = df.rename(columns={'Unnamed: 1':'country'})
df = df[df['country'].isin(countries)]
df.columns
# Out:
# Index(['Region/Country/Area', 'country', 'Year', 'Series', 'Value',
#        'Footnotes', 'Source'],
#       dtype='object')

# %%
dfp = df[['country', 'Year', 'Series', 'Value']]
dfp1 = dfp[dfp['Series']=='Consumer price index: General']
dfp1 = dfp1.rename(columns={'Value':'CPIG'})
dfp1 = dfp1[['country', 'Year', 'CPIG']]

dfp2 = dfp[dfp['Series']=='Consumer price index: Food']
dfp2 = dfp2.rename(columns={'Value':'CPIF'})
dfp2 = dfp2[['country', 'Year', 'CPIF']]

dfcpi = dfp1.merge(dfp2,on=['country', 'Year'])
del df,dfp,dfp1,dfp2

# %% [markdown]
# ### Imports and Exports

# %%
filename = './datasets/UN/SYB61_T21_Total Imports, Exports and Balance of Trade.csv'
df = pd.read_csv(filename,encoding='latin1',header=[1])
df = df.rename(columns={'Unnamed: 1':'country'})
df = df[df['country'].isin(countries)]
df.columns
# Out:
# Index(['Region/Country/Area', 'country', 'Year', 'Series', 'System of trade',
#        'System of trade footnote', 'Value', 'Footnotes', 'Source'],
#       dtype='object')

# %%
dfp = df[['country', 'Year', 'Series', 'Value']]
dfp1 = dfp[dfp['Series']=='Imports CIF (millions of US dollars)']
dfp1 = dfp1.rename(columns={'Value':'Imports'})
dfp1 = dfp1[['country', 'Year', 'Imports']]

dfp2 = dfp[dfp['Series']=='Exports FOB (millions of US dollars)']
dfp2 = dfp2.rename(columns={'Value':'Exports'})
dfp2 = dfp2[['country', 'Year', 'Exports']]
dfcpi
dfimex = dfp1.merge(dfp2,on=['country', 'Year'])
del df,dfp,dfp1,dfp2

# %% [markdown]
# ### Crime

# %%
filename = './datasets/UN/SYB62_T12_201904_Intentional homicides and Other Crimes.csv'
df = pd.read_csv(filename,encoding='latin1',header=[1])
df = df.rename(columns={'Unnamed: 1':'country'})
df = df[df['country'].isin(countries)]
df.columns
# Out:
# Index(['Region/Country/Area', 'country', 'Year', 'Series', 'Value',
#        'Footnotes', 'Source'],
#       dtype='object')

# %%
df = df[df['Series']=='Intentional homicide rates per 100,000']
df = df.rename(columns={'Value':'homicide'})
dfcrime = df[['country', 'Year', 'homicide']]
del df

# %% [markdown]
# ### Migrants and Refugees

# %%
filename = './datasets/UN/SYB61_T04_International Migrants and Refugees.csv'
df = pd.read_csv(filename,encoding='latin1',header=[1])
df = df.rename(columns={'Unnamed: 1':'country'})
df = df[df['country'].isin(countries)]
df.columns
# Out:
# Index(['Region/Country/Area', 'country', 'Year', 'Series', 'Value',
#        'Footnotes', 'Source'],
#       dtype='object')

# %%
df = df[df['Series']=='International migrant stock: Both sexes (% total population)']
df = df.rename(columns={'Value':'migrants'})
dfmig = df[['country', 'Year', 'migrants']]
del df

# %% [markdown]
# ### GDP and GDP Per Capita

# %%
filename = './datasets/UN/SYB62_T13_201904_GDP and GDP Per Capita.csv'
df = pd.read_csv(filename,encoding='latin1',header=[1])
df = df.rename(columns={'Unnamed: 1':'country'})
df = df[df['country'].isin(countries)]
df.columns
# Out:
# Index(['Region/Country/Area', 'country', 'Year', 'Series', 'Value',
#        'Footnotes', 'Source'],
#       dtype='object')

# %%
dfp = df[['country', 'Year', 'Series', 'Value']]
dfp1 = dfp[dfp['Series']=='GDP in current prices (millions of US dollars)']
dfp1 = dfp1.rename(columns={'Value':'GDP'})
dfp1 = dfp1[['country', 'Year', 'GDP']]

dfp2 = dfp[dfp['Series']=='GDP per capita (US dollars)']
dfp2 = dfp2.rename(columns={'Value':'PPP'})
dfp2 = dfp2[['country', 'Year', 'PPP']]

dfgdp = dfp1.merge(dfp2,on=['country', 'Year'])
del df,dfp,dfp1,dfp2

# %% [markdown]
# ### Tourist-Visitors Arrival and Expenditure

# %%
filename = './datasets/UN/SYB62_T30_201904_Tourist-Visitors Arrival and Expenditure.csv'
df = pd.read_csv(filename,encoding='latin1',header=[1])
df = df.rename(columns={'Unnamed: 1':'country'})
df = df[df['country'].isin(countries)]
df.columns
# Out:
# Index(['Region/Country/Area', 'country', 'Year', 'Series',
#        'Tourism arrivals series type', 'Tourism arrivals series type footnote',
#        'Value', 'Footnotes', 'Source'],
#       dtype='object')

# %%
dfp = df[['country', 'Year', 'Series', 'Value']]
dfp1 = dfp[dfp['Series']=='Tourism expenditure (millions of US dollars)']
dfp1 = dfp1.rename(columns={'Value':'tourexp'})
dfp1 = dfp1[['country', 'Year', 'tourexp']]

dfp2 = dfp[dfp['Series']=='Tourist/visitor arrivals (thousands)']
dfp2 = dfp2.rename(columns={'Value':'tvarrival'})
dfp2 = dfp2[['country', 'Year', 'tvarrival']]

dftour = dfp1.merge(dfp2,on=['country', 'Year'])
del df,dfp,dfp1,dfp2

# %% [markdown]
# ### Public Expenditure on Education

# %%
filename = './datasets/UN/SYB62_T09_201905_Public Expenditure on Education.csv'
df = pd.read_csv(filename,encoding='latin1',header=[1])
df = df.rename(columns={'Unnamed: 1':'country'})
df = df[df['country'].isin(countries)]
df.columns
# Out:
# Index(['Region/Country/Area', 'country', 'Year', 'Series', 'Value',
#        'Footnotes', 'Source'],
#       dtype='object')

# %%
df = df[df['Series']=='Public expenditure on education (% of government expenditure)']
df = df.rename(columns={'Value':'education'})
dfedu = df[['country', 'Year', 'education']]
del df

# %% [markdown]
# ### Index of industrial production

# %%
filename = './datasets/UN/SYB58_T25 Index of industrial production.csv'
df = pd.read_csv(filename,encoding='latin1',header=[1])
df = df.rename(columns={'Unnamed: 1':'country'})
df = df[df['country'].isin(countries)]
df.columns
# Out:
# Index(['Region/Country/Area', 'country', 'Series', 'Year', 'Value',
#        'Footnotes', 'Source'],
#       dtype='object')

# %%
df = df[df['Series']=='Index of industrial production: Manufacturing (Index base: 2005=100)']
df = df.rename(columns={'Value':'Manufacturing'})
dfmanu = df[['country', 'Year', 'Manufacturing']]
del df

# %%
data_frames = [df_internet,dfimex,dfmig,dfgdp,dfedu]

from functools import reduce
df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['country', 'Year'],
                                            how='inner'), data_frames)
cols = df_merged.loc[:, df_merged.dtypes == object].columns
for i in cols:
    df_merged[i] = df_merged[i].apply(lambda x: x.replace(',',''))
df_merged.shape
# Out:
# (320, 9)

# %%
df_merged.to_csv('countries_2.scv')

# %%
df_merged.to_csv('UN_cleaned.csv')

# %%
df_merged.columns
# Out:
# Index(['country', 'Year', 'internetusage', 'CPIG', 'CPIF', 'Imports',
#        'Exports', 'homicide', 'migrants', 'GDP', 'PPP', 'tourexp', 'tvarrival',
#        'education', 'Manufacturing'],
#       dtype='object')

# %%
x = df_merged['internetusage'].values.astype(float)
y = df_merged['tvarrival'].values.astype(float)
plt.plot(x,y,'.')
# plt.xscale('log')
# plt.yscale('log')

# %%
data_frames = [df_internet,dfcpi,dfimex,dfmig,dfgdp,dftour]

from functools import reduce
df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['country', 'Year'],
                                            how='inner'), data_frames)
cols = df_merged.loc[:, df_merged.dtypes == object].columns
for i in cols:
    df_merged[i] = df_merged[i].apply(lambda x: x.replace(',',''))
df_merged.shape
# Out:
# (451, 12)

# %%
df_merged
# Out:
#                         country  Year  internetusage   CPIG     CPIF  Imports  \
# 0                       Albania  2010           45.0    100      100     4603
# 1                       Albania  2015           63.3  111.4    118.8     4320
# 2                       Albania  2017           71.8  115.1    127.3     5826
# 3                       Algeria  2010           12.5    100      100    41000
# 4                       Algeria  2015           38.2  126.7    131.3    51803
# 5                       Algeria  2017           47.7  142.4    142.5    46053
# 6                        Angola  2005            1.1   53.7     45.5     8321
# 7                        Angola  2010            2.8    100      100    18143
# 8                        Angola  2015           12.4  161.1    167.3    16758
# 9                        Angola  2017           14.3  280.8    286.6     3845
# 10                     Anguilla  2010           49.6    100      100      150
# 11                     Anguilla  2015           76.0  105.1    111.4      204
# 12                    Argentina  2017           75.8  112.9    111.7    66899
# 13                      Armenia  2010           25.0    100      100     3782
# 14                      Armenia  2015           59.1  124.8    127.1     3257
# 15                      Armenia  2017           69.7  124.2    127.9     4077
# 16                        Aruba  2005           25.4   84.1     73.6     1030
# 17                        Aruba  2010           62.0    100      100     1071
# 18                        Aruba  2015           88.7  103.4    111.9     1165
# 19                        Aruba  2017           97.2    102    112.5     1152
# 20                    Australia  2010           76.0    100      100   201703
# 21                    Australia  2015           84.6    112    107.6   200114
# 22                    Australia  2017           86.5  115.7    109.2   228442
# 23                      Austria  2005           58.0   91.4     88.1   119950
# 24                      Austria  2010           75.2    100      100   150593
# 25                      Austria  2015           83.9  110.7    114.4   147935
# 26                      Austria  2017           87.9    114      118   166551
# 27                   Azerbaijan  2010           46.0    100      100     6597
# 28                   Azerbaijan  2015           77.0  117.7    119.6     9211
# 29                   Azerbaijan  2017           79.0  149.5    159.8     8767
# ..                          ...   ...            ...    ...      ...      ...
# 421                      Turkey  2015           53.7  146.1    157.3   207207
# 422                      Turkey  2017           64.7    175    187.5   233792
# 423                      Uganda  2015           17.8  150.8    160.7     5528
# 424                      Uganda  2017           23.7  167.9    186.8     4809
# 425                     Ukraine  2010           23.3    100      100    60737
# 426                     Ukraine  2015           48.9  180.5    166.6    37516
# 427                     Ukraine  2017           57.1  235.3    204.9    49439
# 428              United Kingdom  2005           70.0   87.4     78.5   528461
# 429              United Kingdom  2010           85.0    100      100   627618
# 430              United Kingdom  2015           92.0  111.9    109.8   630251
# 431     United Rep. of Tanzania  2015           10.0    158     96.6    14706
# 432     United Rep. of Tanzania  2017           16.0    175    113.3     7706
# 433    United States of America  2005           68.0   89.6     87.9  1732321
# 434    United States of America  2010           71.7    100      100  1968260
# 435    United States of America  2015           74.6  108.7    112.2  2313425
# 436    United States of America  2017           75.2  112.4    110.5  2408395
# 437                     Uruguay  2005           20.1   70.5     64.3     3879
# 438                     Uruguay  2010           46.4    100      100     8622
# 439                     Uruguay  2015           64.6  150.1    158.8     9489
# 440                     Uruguay  2017           68.3  174.8      179     8458
# 441                     Vanuatu  2010            8.0    100      100      276
# 442                     Vanuatu  2015           22.4  107.1    109.2      355
# 443  Venezuela (Boliv. Rep. of)  2010           37.4    100      100    32343
# 444  Venezuela (Boliv. Rep. of)  2015           60.0    772  1487.20    40146
# 445                    Viet Nam  2017           49.6  155.8      103   218338
# 446                      Zambia  2015           21.0    144    151.2     8420
# 447                      Zambia  2017           27.9  180.9    193.9     9145
# 448                    Zimbabwe  2010            6.4    100      100     5852
# 449                    Zimbabwe  2015           22.7  106.2    103.6     6002
# 450                    Zimbabwe  2017           27.1  105.5    102.7     5449
#
#      Exports migrants       GDP    PPP tourexp tvarrival
# 0       1550      1.8     11927   4056    1778      2191
# 1       1930      1.8     11387   3895    1613      3784
# 2       2262      1.8     13039   4450    2049      4643
# 3      57051      0.6    161207   4463     324      2070
# 4      34796      0.6    165979   4163     347      1710
# 5      35191      0.6    167555   4055     172      2451
# 6      23835      0.3     36971   1891     103       210
# 7      52612      0.3     83799   3586     726       425
# 8      33048      2.3    116194   4171    1171       592
# 9      13311      2.1    126506   4247     884       261
# 10        12     37.1       268  19459      99        62
# 11        11     37.4       331  22622     142        73
# 12     58384      4.9    637486  14400    5514      6720
# 13      1011      7.7      9875   3432     694       684
# 14      1483      6.6     10553   3618     956      1192
# 15      2041      6.5     11537   3937    1140      1495
# 16       106     32.5      2331  23303    1097       733
# 17       125     33.8      2391  23513    1254       824
# 18        80     34.6      2692  25796    1664      1225
# 19        95     34.5      2701  25655    1733      1071
# 20    212109     26.6   1297259  58646   31064      5790
# 21    187792     28.2   1246800  52388   30872      7450
# 22    230163     28.8   1408676  57613   43982      8815
# 23    117722     13.8    315967  38282   16243     19952
# 24    144882     15.2    391893  46599   18758     22004
# 25    145277     17.2    381806  43994   20416     26728
# 26    159785       19    416836  47718   22408     29460
# 27     21278      3.1     52906   5857     792      1280
# 28     11327      2.7     53076   5519    2535      1922
# 29     13798      2.6     40749   4146    3214      2454
# ..       ...      ...       ...    ...     ...       ...
# 421   143850      5.3    859794  10985   35597     39478
# 422   157055        6    851542  10546   31870     37601
# 423     2267        3     25098    625    1046      1303
# 424     2852      3.9     27699    646     940      1402
# 425    51430     10.5    136012   2970    4696     21203
# 426    38127       11     91031   2038    1662     12428
# 427    43428     11.2    112154   2536    1999     14230
# 428   392744      9.8   2525013  41883   41736     28039
# 429   422014       12   2452900  38746   40526     28295
# 430   466296     12.9   2896421  44290   65454     34436
# 431     5854      0.8     45628    870    1924      1104
# 432     4500      0.9     52090    934    2284      1275
# 433   904339     13.3  13036637  44173  122077     49206
# 434  1278099     14.3  14992052  48574  167996     60010
# 435  1501846     15.1  18219297  56948  249183     77774
# 436  1546069     15.3  19485394  60055  251361     76941
# 437     3422      2.5     17363   5221     699      1808
# 438     6724      2.3     40285  11938    1669      2353
# 439     7670      2.3     53274  15525    2070      2773
# 440     7889      2.3     59180  17120    2666      3674
# 441       46      1.3       701   2966     242        97
# 442       39      1.2       760   2871     254        90
# 443    66963      4.6    393806  13566     885       526
# 444    37236      4.5    344375  11054     654       789
# 445   203526      0.1    223780   2342    8890     12922
# 446     6983        1     21243   1319     660       932
# 447     8363      0.9     25868   1513     653      1083
# 448     3199      2.8     10142    720     135      2239
# 449     2704      2.6     16305   1033     191      2057
# 450     3465      2.4     18037   1091     158      2423
#
# [451 rows x 12 columns]

# %%
df_merged
# Out:
#                       country  Year  internetusage  Imports  Exports migrants  \
# 0                 Afghanistan  2010            4.0     5154      388      0.4
# 1                 Afghanistan  2015            8.3     7723      571      1.5
# 2                 Afghanistan  2017           11.4     7384      700      0.4
# 3                     Albania  2005            6.0     2614      658      2.1
# 4                     Albania  2015           63.3     4320     1930      1.8
# 5                      Angola  2005            1.1     8321    23835      0.3
# 6                      Angola  2010            2.8    18143    52612      0.3
# 7                   Argentina  2005           17.7    28689    40106      4.3
# 8                   Argentina  2010           45.0    56792    68174      4.4
# 9                     Armenia  2005            5.3     1692      937     15.7
# 10                    Armenia  2010           25.0     3782     1011      7.7
# 11                  Australia  2005           63.0   125221   106011     24.1
# 12                  Australia  2010           76.0   201703   212109     26.6
# 13                  Australia  2015           84.6   200114   187792     28.2
# 14                    Austria  2005           58.0   119950   117722     13.8
# 15                    Austria  2010           75.2   150593   144882     15.2
# 16                    Austria  2015           83.9   147935   145277     17.2
# 17                 Azerbaijan  2005            8.0     4211     4347      3.5
# 18                 Azerbaijan  2010           46.0     6597    21278      3.1
# 19                    Bahrain  2015           93.5    16378    16684     51.3
# 20                    Bahrain  2017           95.9    12613     9666     48.4
# 21                   Barbados  2005           52.5     1672      361     11.2
# 22                   Barbados  2010           65.1     1196      314     11.7
# 23                   Barbados  2017           81.8     1600      485     12.1
# 24                    Belarus  2005            9.0    16699    15977     11.5
# 25                    Belarus  2010           31.8    34884    25283     11.5
# 26                    Belarus  2017           74.4    34235    29207     11.4
# 27                    Belgium  2005           55.8   319085   335692      8.4
# 28                    Belgium  2010           75.0   391256   407596     10.2
# 29                    Belgium  2015           85.1   371025   397739     11.1
# ..                        ...   ...            ...      ...      ...      ...
# 290                    Sweden  2015           90.6   138361   140001     16.4
# 291               Switzerland  2005           70.1   126574   130930     24.4
# 292               Switzerland  2010           83.9   176281   195609     26.5
# 293               Switzerland  2015           87.5   253152   291959       29
# 294                Tajikistan  2005            0.3     1329      905      4.1
# 295                Tajikistan  2010           11.6     2659     1207      3.6
# 296                Tajikistan  2015           19.0     3435      891      3.2
# 297                  Thailand  2005           15.0   118164   110110      3.3
# 298                  Thailand  2010           22.4   182393   195312      4.8
# 299               Timor-Leste  2010            3.0      298       42        1
# 300                      Togo  2005            1.8      593      360      3.6
# 301                      Togo  2010            3.0     1205      648      3.9
# 302                   Tunisia  2005            9.7    13174    10494      0.3
# 303                   Tunisia  2010           36.8    22215    16427      0.4
# 304                   Tunisia  2015           46.5    20223    14073      0.5
# 305                    Turkey  2015           53.7   207207   143850      5.3
# 306                    Uganda  2010           12.5     4664     1619      1.6
# 307                    Uganda  2017           23.7     4809     2852      3.9
# 308                   Ukraine  2005            3.7    36122    34228     10.8
# 309            United Kingdom  2005           70.0   528461   392744      9.8
# 310            United Kingdom  2010           85.0   627618   422014       12
# 311   United Rep. of Tanzania  2005            1.1     3247     1672        2
# 312   United Rep. of Tanzania  2010            2.9     8013     4051      0.7
# 313  United States of America  2010           71.7  1968260  1278099     14.3
# 314                   Uruguay  2005           20.1     3879     3422      2.5
# 315                Uzbekistan  2017           52.3    12998    13894      3.6
# 316                   Vanuatu  2017           25.7      313       38      1.2
# 317                  Viet Nam  2010           30.7    84839    72237      0.1
# 318                    Zambia  2005            2.9     2558     1810      2.1
# 319                  Zimbabwe  2010            6.4     5852     3199      2.8
#
#           GDP    PPP  education
# 0       16078    558    17.0676
# 1       20608    611    12.5090
# 2       21993    619    15.6614
# 3        8052   2615    11.3580
# 4       11387   3895    11.3177
# 5       36971   1891     7.9924
# 6       83799   3586     8.6848
# 7      200622   5125    15.8082
# 8      426487  10346    15.0483
# 9        5226   1753    13.6481
# 10       9875   3432    12.4005
# 11     760397  37571    13.5851
# 12    1297259  58646    14.3276
# 13    1246800  52388    14.0758
# 14     315967  38282    10.2619
# 15     391893  46599    10.7891
# 16     381806  43994    10.6935
# 17      13245   1551    13.2232
# 18      52906   5857     8.7008
# 19      31126  22689     7.2974
# 20      35326  23668     7.1804
# 21       3897  14223    18.2430
# 22       4365  15613    18.0963
# 23       4713  16494    12.8792
# 24      31232   3246    12.6201
# 25      57232   6042    11.7781
# 26      54441   5750    12.2817
# 27     387356  36727    11.1742
# 28     483548  44205    12.0132
# 29     455838  40383    12.1689
# ..        ...    ...        ...
# 290    498118  51018    15.5033
# 291    408697  55153    15.8207
# 292    583783  74538    15.3909
# 293    679832  81713    15.5278
# 294      2312    337    15.2934
# 295      5642    738    15.3315
# 296      7855    919    16.4434
# 297    189318   2894    20.5468
# 298    341105   5075    16.2226
# 299      3999   3604     9.1542
# 300      2281    401    17.6781
# 301      3426    527    19.6158
# 302     32272   3194    26.6957
# 303     44051   4140    24.8468
# 304     43152   3828    22.8985
# 305    859794  10985    12.8390
# 306     19683    580    10.1049
# 307     27699    646    12.0089
# 308     89239   1903    13.7387
# 309   2525013  41883    13.1742
# 310   2452900  38746    13.0260
# 311     18072    471    18.1431
# 312     31105    694    19.6480
# 313  14992052  48574    13.1507
# 314     17363   5221     9.4367
# 315     49677   1557    19.9572
# 316       864   3128    11.7827
# 317    115932   1310    17.1145
# 318      8332    691     7.7297
# 319     10142    720     8.7209
#
# [320 rows x 9 columns]

# %%
pd.read_csv('Credit.csv')
# Out:
#      Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0             1   14.891   3606     283      2   34         11    Male
# 1             2  106.025   6645     483      3   82         15  Female
# 2             3  104.593   7075     514      4   71         11    Male
# 3             4  148.924   9504     681      3   36         11  Female
# 4             5   55.882   4897     357      2   68         16    Male
# 5             6   80.180   8047     569      4   77         10    Male
# 6             7   20.996   3388     259      2   37         12  Female
# 7             8   71.408   7114     512      2   87          9    Male
# 8             9   15.125   3300     266      5   66         13  Female
# 9            10   71.061   6819     491      3   41         19  Female
# 10           11   63.095   8117     589      4   30         14    Male
# 11           12   15.045   1311     138      3   64         16    Male
# 12           13   80.616   5308     394      1   57          7  Female
# 13           14   43.682   6922     511      1   49          9    Male
# 14           15   19.144   3291     269      2   75         13  Female
# 15           16   20.089   2525     200      3   57         15  Female
# 16           17   53.598   3714     286      3   73         17  Female
# 17           18   36.496   4378     339      3   69         15  Female
# 18           19   49.570   6384     448      1   28          9  Female
# 19           20   42.079   6626     479      2   44          9    Male
# 20           21   17.700   2860     235      4   63         16  Female
# 21           22   37.348   6378     458      1   72         17  Female
# 22           23   20.103   2631     213      3   61         10    Male
# 23           24   64.027   5179     398      5   48          8    Male
# 24           25   10.742   1757     156      3   57         15  Female
# 25           26   14.090   4323     326      5   25         16  Female
# 26           27   42.471   3625     289      6   44         12  Female
# 27           28   32.793   4534     333      2   44         16    Male
# 28           29  186.634  13414     949      2   41         14  Female
# 29           30   26.813   5611     411      4   55         16  Female
# ..          ...      ...    ...     ...    ...  ...        ...     ...
# 370         371   35.610   6135     466      4   40         12    Male
# 371         372   39.116   2150     173      4   75         15    Male
# 372         373   19.782   3782     293      2   46         16  Female
# 373         374   55.412   5354     383      2   37         16  Female
# 374         375   29.400   4840     368      3   76         18  Female
# 375         376   20.974   5673     413      5   44         16  Female
# 376         377   87.625   7167     515      2   46         10  Female
# 377         378   28.144   1567     142      3   51         10    Male
# 378         379   19.349   4941     366      1   33         19    Male
# 379         380   53.308   2860     214      1   84         10    Male
# 380         381  115.123   7760     538      3   83         14  Female
# 381         382  101.788   8029     574      2   84         11    Male
# 382         383   24.824   5495     409      1   33          9    Male
# 383         384   14.292   3274     282      9   64          9    Male
# 384         385   20.088   1870     180      3   76         16    Male
# 385         386   26.400   5640     398      3   58         15  Female
# 386         387   19.253   3683     287      4   57         10    Male
# 387         388   16.529   1357     126      3   62          9    Male
# 388         389   37.878   6827     482      2   80         13  Female
# 389         390   83.948   7100     503      2   44         18    Male
# 390         391  135.118  10578     747      3   81         15  Female
# 391         392   73.327   6555     472      2   43         15  Female
# 392         393   25.974   2308     196      2   24         10    Male
# 393         394   17.316   1335     138      2   65         13    Male
# 394         395   49.794   5758     410      4   40          8    Male
# 395         396   12.096   4100     307      3   32         13    Male
# 396         397   13.364   3838     296      5   65         17    Male
# 397         398   57.872   4171     321      5   67         12  Female
# 398         399   37.728   2525     192      1   44         13    Male
# 399         400   18.701   5524     415      5   64          7  Female
#
#     Student Married         Ethnicity  Balance
# 0        No     Yes         Caucasian      333
# 1       Yes     Yes             Asian      903
# 2        No      No             Asian      580
# 3        No      No             Asian      964
# 4        No     Yes         Caucasian      331
# 5        No      No         Caucasian     1151
# 6        No      No  African American      203
# 7        No      No             Asian      872
# 8        No      No         Caucasian      279
# 9       Yes     Yes  African American     1350
# 10       No     Yes         Caucasian     1407
# 11       No      No         Caucasian        0
# 12       No     Yes             Asian      204
# 13       No     Yes         Caucasian     1081
# 14       No      No  African American      148
# 15       No     Yes  African American        0
# 16       No     Yes  African American        0
# 17       No     Yes             Asian      368
# 18       No     Yes             Asian      891
# 19       No      No             Asian     1048
# 20       No      No             Asian       89
# 21       No      No         Caucasian      968
# 22       No     Yes  African American        0
# 23       No     Yes  African American      411
# 24       No      No         Caucasian        0
# 25       No     Yes  African American      671
# 26      Yes      No         Caucasian      654
# 27       No      No  African American      467
# 28       No     Yes  African American     1809
# 29       No      No         Caucasian      915
# ..      ...     ...               ...      ...
# 370      No      No         Caucasian      992
# 371      No      No         Caucasian        0
# 372     Yes      No         Caucasian      840
# 373     Yes     Yes         Caucasian     1003
# 374      No     Yes         Caucasian      588
# 375      No     Yes         Caucasian     1000
# 376      No      No  African American      767
# 377      No     Yes         Caucasian        0
# 378      No     Yes         Caucasian      717
# 379      No     Yes         Caucasian        0
# 380      No      No  African American      661
# 381      No     Yes         Caucasian      849
# 382     Yes      No         Caucasian     1352
# 383      No     Yes         Caucasian      382
# 384      No      No  African American        0
# 385      No      No             Asian      905
# 386      No      No  African American      371
# 387      No      No             Asian        0
# 388      No      No         Caucasian     1129
# 389      No      No         Caucasian      806
# 390      No     Yes             Asian     1393
# 391      No      No         Caucasian      721
# 392      No      No             Asian        0
# 393      No      No  African American        0
# 394      No      No         Caucasian      734
# 395      No     Yes         Caucasian      560
# 396      No      No  African American      480
# 397      No     Yes         Caucasian      138
# 398      No     Yes         Caucasian        0
# 399      No      No             Asian      966
#
# [400 rows x 12 columns]

# %%
pd.read_csv('./UN_cleaned.csv')
